# %% [markdown]
# # Polynomial Regression model to predict salary based on the position

# %%
#Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split

# %%
# Reading the dataset
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,1:2].values
y = dataset.iloc[:,2].values

# %%
#Fitting Linear Regression model to the dataset
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X,y)
y_pred = linear_reg.predict(X)

# %%
#Fitting polynomial regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree =2)
X_poly = poly_reg.fit_transform(X)
linear_reg2 = LinearRegression()
linear_reg2.fit(X_poly,y)
y_pred1 = linear_reg2.predict(X_poly)

# %%
#Visulazing Linear Regression model results
plt.scatter(X,y,color="red")
plt.plot(X,y_pred,color="blue")
plt.title("Actual vs Predicted(Linear Regression Model)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
#Visualizing Polynomial Regression model results
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y,color="red")
plt.plot(X_grid,linear_reg2.predict(poly_reg.fit_transform(X_grid)),color="blue")
plt.title("Actual vs Predicted (Polynomial Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %%
#predicting new result using Linear regression model (Employee Level:6.5)
y_predicted = linear_reg.predict([[6.5]])
y_predicted
# Out:
# array([330378.78787879])

# %%
y_predicted_poly = linear_reg2.predict(poly_reg.fit_transform([[6.5]]))
y_predicted_poly
# Out:
# array([189498.10606061])

# %% [markdown]
# ### We can notice that the result from polynomial regression model is very close to the actual and therefore this model could be used to effectively to predict the salaries of the employees
